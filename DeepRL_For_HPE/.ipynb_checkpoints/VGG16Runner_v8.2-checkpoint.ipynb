# %%
from DatasetHandler.BiwiBrowser import *
from LSTM_VGG16.LSTM_VGG16Helper import *
# %matplotlib inline
# Out:
# /home/mcicek/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
output_begin = 4
num_outputs = 1

# %%
timesteps = 100 # TimeseriesGenerator Handles overlapping
in_epochs = 20
out_epochs = 1
train_batch_size = 1
test_batch_size = 1

# %%
subjectList = [1] #, 2, 3, 4, 5, 7, 8, 11, 12, 14 except [6, 13, 10, ]
testSubjects = [1]

# %%
num_datasets = len(subjectList)

# %%
def getImageModel(num_outputs = num_outputs):
    inp = BIWI_Frame_Shape
    vgg_model = VGG16(weights='imagenet', include_top=False, input_shape = BIWI_Frame_Shape)
    rnn = Sequential()
    rnn.add(TimeDistributed(vgg_model, input_shape=(timesteps, inp[0], inp[1], inp[2])))
    rnn.add(TimeDistributed(Flatten()))
    
    rnn.add(TimeDistributed(Dense(1024, activation='relu')))
    rnn.add(LSTM(128, dropout=0.4, recurrent_dropout=0.2))

    for layer in rnn.layers[:15]:
        layer.trainable = False
    return rnn

# %%
def getAngleModel(num_outputs = num_outputs):
    rnn = Sequential()
    #rnn.add(TimeDistributed(vgg_model))
    #rnn.add(TimeDistributed(Dense(1024, activation='relu')))
    rnn.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2, input_shape=(timesteps, num_outputs)))
    rnn.add(Dense(num_outputs))
    rnn.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return rnn

# %%
def getFinalModel(imageModel, angleModel, num_outputs = num_outputs):
    inp = BIWI_Frame_Shape
    vgg_model = VGG16(weights='imagenet', include_top=False, input_shape = BIWI_Frame_Shape)
    rnn = Sequential()
    rnn.add(TimeDistributed(Merge([imageModel, angleModel], mode='concat')))
    rnn.add(Dense(num_outputs))
    rnn.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return rnn

# %%
keras.backend.clear_session()
full_model = getAngleModel(num_outputs = num_outputs)

# %%
full_model = trainAngleModelForEpochs(full_model, out_epochs, subjectList, testSubjects, timesteps, False, output_begin, num_outputs, batch_size = train_batch_size, in_epochs = in_epochs)
# Out:
# All frames and annotations from 1 datasets have been read by 2019-01-01 21:56:02.314678
# 1. set (Dataset 1) being trained for epoch 1!
# Epoch 1/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0206 - mean_absolute_error: 0.0991
# Epoch 2/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0176 - mean_absolute_error: 0.0931
# Epoch 3/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0141 - mean_absolute_error: 0.0816
# Epoch 4/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0088 - mean_absolute_error: 0.0683
# Epoch 5/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0101 - mean_absolute_error: 0.0734
# Epoch 6/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0097 - mean_absolute_error: 0.0745
# Epoch 7/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0086 - mean_absolute_error: 0.0657
# Epoch 8/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0073 - mean_absolute_error: 0.0636
# Epoch 9/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0086 - mean_absolute_error: 0.0671
# Epoch 10/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0073 - mean_absolute_error: 0.0599
# Epoch 11/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0062 - mean_absolute_error: 0.0552
# Epoch 12/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0039 - mean_absolute_error: 0.0455
# Epoch 13/20
# 398/398 [==============================] - 28s 71ms/step - loss: 0.0066 - mean_absolute_error: 0.0540
# Epoch 14/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0059 - mean_absolute_error: 0.0549
# Epoch 15/20
# 398/398 [==============================] - 28s 71ms/step - loss: 0.0061 - mean_absolute_error: 0.0543
# Epoch 16/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0070 - mean_absolute_error: 0.0513
# Epoch 17/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0066 - mean_absolute_error: 0.0570
# Epoch 18/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0050 - mean_absolute_error: 0.0500
# Epoch 19/20
# 398/398 [==============================] - 28s 70ms/step - loss: 0.0039 - mean_absolute_error: 0.0455
# Epoch 20/20
# 398/398 [==============================] - 28s 71ms/step - loss: 0.0056 - mean_absolute_error: 0.0522
# Epoch 1 completed!

# %%
#[1]
test_generators, test_labelSets = getTestBiwiForAngleModel(testSubjects, timesteps, False, output_begin, num_outputs, batch_size = test_batch_size)
test_gen, test_labels = test_generators[0], test_labelSets[0]
# Out:
# All frames and annotations from 1 datasets have been read by 2019-01-01 22:05:30.149234

# %%
predictions = full_model.predict_generator(test_gen)
output1 = numpy.concatenate((test_labels[timesteps:, :1], predictions[:, :1]), axis=1)

# %%
plt.figure(figsize=(30,10))
plt.plot(output1)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd4a98a9630>,
#  <matplotlib.lines.Line2D at 0x7fd4a98a9780>]
